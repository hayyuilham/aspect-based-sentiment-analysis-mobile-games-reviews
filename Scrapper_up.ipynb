# %% [markdown]
# Instalasi library web scrapper

# %%
pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.8/dist-packages (1.2.3)

# %%
pip install langdetect
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: langdetect in /usr/local/lib/python3.8/dist-packages (1.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from langdetect) (1.15.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install -qq watermark

# %%
# %reload_ext watermark
# %watermark -v -p pandas,matplotlib,seaborn,google_play_scraper
# Out:
# Python implementation: CPython
# Python version       : 3.8.10
# IPython version      : 7.9.0
#
# pandas             : 1.3.5
# matplotlib         : 3.5.3
# seaborn            : 0.11.2
# google_play_scraper: 1.2.3

# %%
import json
import pandas as pd
from tqdm import tqdm

import seaborn as sns
import matplotlib.pyplot as plt

from pygments import highlight
from pygments.lexers import JsonLexer
from pygments.formatters import TerminalFormatter

from google_play_scraper import Sort, reviews, app
from langdetect import detect
from langdetect.lang_detect_exception import LangDetectException

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

sns.set(style='whitegrid', palette='muted', font_scale=1.2)

# %%
app_packages = [
  'com.riotgames.league.wildrift',
  'com.dts.freefireth',
  'com.mobile.legends',
  'com.wildlife.games.battle.royale.free.zooba',
  'com.rsg.heroesevolved' 
]

# %%
app_infos = []

for ap in tqdm(app_packages):
  info = app(ap, lang='en', country='us')
  del info['comments']
  app_infos.append(info)
# Out:
# 100%|██████████| 5/5 [00:01<00:00,  3.33it/s]

# %%
len(app_infos)
# Out:
# 5

# %%
def print_json(json_object):
  json_str = json.dumps(
    json_object, 
    indent=2, 
    sort_keys=True, 
    default=str
  )
  print(highlight(json_str, JsonLexer(), TerminalFormatter()))

# %%
app_infos_df = pd.DataFrame(app_infos)
app_infos_df.to_csv('apps_up.csv', index=None, header=True)

# %%
# app_reviews = []

# for ap in tqdm(app_packages):
#   # Mendapatkan informasi mengenai aplikasi
#   app_info = app(ap, lang='en', country='us')

#   rvs, _ = reviews(
#         ap,
#         lang='en',
#         country='en',
#         sort=Sort.NEWEST,
#         count=30000
#         )
#    # Menambahkan nama aplikasi ke setiap ulasan
#   for r in rvs:
#         r['app_name'] = app_info['title']
        
#   app_reviews.extend(rvs)

# %%
app_reviews = []

for ap in tqdm(app_packages):
    # Mendapatkan informasi mengenai aplikasi
    app_info = app(ap, lang='en', country='us')

    rvs, _ = reviews(
            ap,
            lang='en',
            country='us',
            sort=Sort.MOST_RELEVANT,
            count=50000
        )

    for r in rvs:
            try:
                # Memeriksa apakah ulasan dalam bahasa Inggris
                if isinstance(r['content'], str) and detect(r['content']) == 'en':
                    # Memeriksa apakah ulasan sudah ada di app_reviews
                    if r not in app_reviews:
                      # Menambahkan nama aplikasi ke setiap ulasan
                        r['app_name'] = app_info['title']
                        app_reviews.append(r)
            except LangDetectException:
                # Mengabaikan ulasan yang tidak dapat diidentifikasi bahasanya
                pass
# Out:
# 100%|██████████| 5/5 [1:28:02<00:00, 1056.47s/it]

# %%
print_json(app_reviews[0])
# Out:
# {
#   "app_name": "League of Legends: Wild Rift",
#   "at": "2023-02-28 23:52:36",
#   "content": "I like this game alot. Game controls smooth game runs smooth graphics are stellar.. however there is a couple dislikes the suspension of players leaving matches. It's a phone app. So there are definitely times your going to have to leave a match. Phone call will do it. And the 6 to 7 minutes of wait time if not more to find a match in the first place. That's the 3 out of 5 star review.",
#   "repliedAt": null,
#   "replyContent": null,
#   "reviewCreatedVersion": "4.0.0.6270",
#   "reviewId": "0db5c544-3b32-49c8-ac71-55623182eabf",
#   "score": 3,
#   "thumbsUpCount": 0,
#   "userImage": "https://play-lh.googleusercontent.com/a/AGNmyxY6O1gvBzVOUmRa2RFYJwdI28dm3YjIvn2EsffL=mo",
#   "userName": "Oklahoma Hound"
# }

# %%
len(app_reviews)
# Out:
# 225892

# %%
app_reviews_df = pd.DataFrame(app_reviews)

# %%
app_dup = app_reviews_df.duplicated(subset=['content'])

# %%
app_dup
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 225887    False
# 225888    False
# 225889    False
# 225890    False
# 225891    False
# Length: 225892, dtype: bool

# %%
app_dup.value_counts()
# Out:
# False    219321
# True       6571
# dtype: int64

# %%
app_reviews_df[app_reviews_df['content'].isnull()]
# Out:
# Empty DataFrame
# Columns: [reviewId, userName, userImage, content, score, thumbsUpCount, reviewCreatedVersion, at, replyContent, repliedAt, app_name]
# Index: []

# %%
app_reviews_df = app_reviews_df.drop_duplicates(subset=['content'])
app_reviews_df
# Out:
#                                     reviewId         userName  \
# 0       0db5c544-3b32-49c8-ac71-55623182eabf   Oklahoma Hound
# 1       29333e61-701d-4b4d-91cb-0246d796b375       Bryan Bush
# 2       dfca10dc-a5e0-400c-bb9e-ca11672e5948  Vincent Agustin
# 3       51323dde-4adb-47c9-8536-c0abebd22412        Andre Koh
# 4       15bf3e31-8ef3-4fd1-9f1b-7dd1ecf6c7b5       Lee Stefan
# ...                                      ...              ...
# 225887  81bce800-f923-4c68-9080-1514fa9e7ce1    A Google user
# 225888  31c34ce0-bf2e-4f59-9720-78cd19cd2b3b    A Google user
# 225889  3a5dffa4-76b3-4242-9189-22e87aa1d5b4    A Google user
# 225890  51ff0526-0d95-414e-8f99-649800bf792c    A Google user
# 225891  1d10c1b9-0fcf-4a24-99d4-abbb87d48e7f    A Google user
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a/AGNmyx...
# 1       https://play-lh.googleusercontent.com/a-/ACB-R...
# 2       https://play-lh.googleusercontent.com/a-/ACB-R...
# 3       https://play-lh.googleusercontent.com/a-/ACB-R...
# 4       https://play-lh.googleusercontent.com/a/AGNmyx...
# ...                                                   ...
# 225887  https://play-lh.googleusercontent.com/EGemoI2N...
# 225888  https://play-lh.googleusercontent.com/EGemoI2N...
# 225889  https://play-lh.googleusercontent.com/EGemoI2N...
# 225890  https://play-lh.googleusercontent.com/EGemoI2N...
# 225891  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                   content  score  \
# 0       I like this game alot. Game controls smooth ga...      3
# 1       For casual players: The most fundamental flaw ...      3
# 2       This game is better than other mobile games bu...      3
# 3       The game is fun and all when you get to play i...      3
# 4       Only exclusive to this game in all games acros...      3
# ...                                                   ...    ...
# 225887           Better than mobile legends hahaah no lag      5
# 225888       This is the good game but not same with dota      5
# 225889           Its da best of all the mobile Moba games      5
# 225890  i like the game very much,but i can not invite...      5
# 225891                           nice job. better than ML      5
#
#         thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 0                   0           4.0.0.6270 2023-02-28 23:52:36         None
# 1                  79           4.0.0.6270 2023-02-07 03:21:16         None
# 2                   0           4.0.0.6270 2023-03-01 16:45:36         None
# 3                 342           4.0.0.6270 2023-01-25 11:28:18         None
# 4                  47           4.0.0.6270 2023-01-25 10:12:39         None
# ...               ...                  ...                 ...          ...
# 225887              0              1.1.7.0 2017-03-25 01:01:02         None
# 225888              0              1.1.7.0 2017-04-07 10:55:46         None
# 225889              0              1.1.7.0 2017-04-04 16:44:54         None
# 225890              0              1.1.7.0 2017-04-10 06:04:01         None
# 225891              0              1.1.7.0 2017-03-26 12:16:59         None
#
#        repliedAt                      app_name
# 0            NaT  League of Legends: Wild Rift
# 1            NaT  League of Legends: Wild Rift
# 2            NaT  League of Legends: Wild Rift
# 3            NaT  League of Legends: Wild Rift
# 4            NaT  League of Legends: Wild Rift
# ...          ...                           ...
# 225887       NaT                Heroes Evolved
# 225888       NaT                Heroes Evolved
# 225889       NaT                Heroes Evolved
# 225890       NaT                Heroes Evolved
# 225891       NaT                Heroes Evolved
#
# [219321 rows x 11 columns]

# %%
app_reviews_df.score.value_counts()
# Out:
# 5    77854
# 1    67617
# 4    29398
# 3    25411
# 2    19041
# Name: score, dtype: int64

# %%
app_reviews_df_clear = app_reviews_df.dropna(subset=['content']).reset_index(drop=True)
app_reviews_df_clear
# Out:
#                                     reviewId         userName  \
# 0       0db5c544-3b32-49c8-ac71-55623182eabf   Oklahoma Hound
# 1       29333e61-701d-4b4d-91cb-0246d796b375       Bryan Bush
# 2       dfca10dc-a5e0-400c-bb9e-ca11672e5948  Vincent Agustin
# 3       51323dde-4adb-47c9-8536-c0abebd22412        Andre Koh
# 4       15bf3e31-8ef3-4fd1-9f1b-7dd1ecf6c7b5       Lee Stefan
# ...                                      ...              ...
# 219316  81bce800-f923-4c68-9080-1514fa9e7ce1    A Google user
# 219317  31c34ce0-bf2e-4f59-9720-78cd19cd2b3b    A Google user
# 219318  3a5dffa4-76b3-4242-9189-22e87aa1d5b4    A Google user
# 219319  51ff0526-0d95-414e-8f99-649800bf792c    A Google user
# 219320  1d10c1b9-0fcf-4a24-99d4-abbb87d48e7f    A Google user
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a/AGNmyx...
# 1       https://play-lh.googleusercontent.com/a-/ACB-R...
# 2       https://play-lh.googleusercontent.com/a-/ACB-R...
# 3       https://play-lh.googleusercontent.com/a-/ACB-R...
# 4       https://play-lh.googleusercontent.com/a/AGNmyx...
# ...                                                   ...
# 219316  https://play-lh.googleusercontent.com/EGemoI2N...
# 219317  https://play-lh.googleusercontent.com/EGemoI2N...
# 219318  https://play-lh.googleusercontent.com/EGemoI2N...
# 219319  https://play-lh.googleusercontent.com/EGemoI2N...
# 219320  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                   content  score  \
# 0       I like this game alot. Game controls smooth ga...      3
# 1       For casual players: The most fundamental flaw ...      3
# 2       This game is better than other mobile games bu...      3
# 3       The game is fun and all when you get to play i...      3
# 4       Only exclusive to this game in all games acros...      3
# ...                                                   ...    ...
# 219316           Better than mobile legends hahaah no lag      5
# 219317       This is the good game but not same with dota      5
# 219318           Its da best of all the mobile Moba games      5
# 219319  i like the game very much,but i can not invite...      5
# 219320                           nice job. better than ML      5
#
#         thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 0                   0           4.0.0.6270 2023-02-28 23:52:36         None
# 1                  79           4.0.0.6270 2023-02-07 03:21:16         None
# 2                   0           4.0.0.6270 2023-03-01 16:45:36         None
# 3                 342           4.0.0.6270 2023-01-25 11:28:18         None
# 4                  47           4.0.0.6270 2023-01-25 10:12:39         None
# ...               ...                  ...                 ...          ...
# 219316              0              1.1.7.0 2017-03-25 01:01:02         None
# 219317              0              1.1.7.0 2017-04-07 10:55:46         None
# 219318              0              1.1.7.0 2017-04-04 16:44:54         None
# 219319              0              1.1.7.0 2017-04-10 06:04:01         None
# 219320              0              1.1.7.0 2017-03-26 12:16:59         None
#
#        repliedAt                      app_name
# 0            NaT  League of Legends: Wild Rift
# 1            NaT  League of Legends: Wild Rift
# 2            NaT  League of Legends: Wild Rift
# 3            NaT  League of Legends: Wild Rift
# 4            NaT  League of Legends: Wild Rift
# ...          ...                           ...
# 219316       NaT                Heroes Evolved
# 219317       NaT                Heroes Evolved
# 219318       NaT                Heroes Evolved
# 219319       NaT                Heroes Evolved
# 219320       NaT                Heroes Evolved
#
# [219321 rows x 11 columns]

# %%
app_reviews_df_clear["at"] = app_reviews_df_clear["at"].astype(str)

# %%
len(app_reviews_df_clear[app_reviews_df_clear["at"].str.contains("2018")])
# Out:
# 6894

# %%
app_reviews_df_clear = app_reviews_df_clear[~app_reviews_df_clear["at"].str.contains("2017|2018|2019")]

# %%
len(app_reviews_df_clear[app_reviews_df_clear["at"].str.contains("2020")])
# Out:
# 55324

# %%
app_reviews_df_clear[app_reviews_df_clear['content'].isnull()]
# Out:
# Empty DataFrame
# Columns: [reviewId, userName, userImage, content, score, thumbsUpCount, reviewCreatedVersion, at, replyContent, repliedAt, app_name]
# Index: []

# %%
app_reviews_df_clear
# Out:
#                                     reviewId          userName  \
# 0       0db5c544-3b32-49c8-ac71-55623182eabf    Oklahoma Hound
# 1       29333e61-701d-4b4d-91cb-0246d796b375        Bryan Bush
# 2       dfca10dc-a5e0-400c-bb9e-ca11672e5948   Vincent Agustin
# 3       51323dde-4adb-47c9-8536-c0abebd22412         Andre Koh
# 4       15bf3e31-8ef3-4fd1-9f1b-7dd1ecf6c7b5        Lee Stefan
# ...                                      ...               ...
# 216858  b94be9c6-4545-4594-b6bd-df3447ad0913       Mayank Gala
# 217573  9cf9def6-9438-43f8-97c8-9963f99d02c6       Johny Nabam
# 217590  2ea2939e-c366-495a-af6c-4a1a7c64dc3f     A Google user
# 217607  9a80facb-af88-480c-ab1e-740eb2abf462  noctix nefarioux
# 218667  7115fa10-8659-4835-975a-8f5fea31515a     A Google user
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a/AGNmyx...
# 1       https://play-lh.googleusercontent.com/a-/ACB-R...
# 2       https://play-lh.googleusercontent.com/a-/ACB-R...
# 3       https://play-lh.googleusercontent.com/a-/ACB-R...
# 4       https://play-lh.googleusercontent.com/a/AGNmyx...
# ...                                                   ...
# 216858  https://play-lh.googleusercontent.com/a-/ACB-R...
# 217573  https://play-lh.googleusercontent.com/a-/ACB-R...
# 217590  https://play-lh.googleusercontent.com/EGemoI2N...
# 217607  https://play-lh.googleusercontent.com/a-/ACB-R...
# 218667  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                   content  score  \
# 0       I like this game alot. Game controls smooth ga...      3
# 1       For casual players: The most fundamental flaw ...      3
# 2       This game is better than other mobile games bu...      3
# 3       The game is fun and all when you get to play i...      3
# 4       Only exclusive to this game in all games acros...      3
# ...                                                   ...    ...
# 216858                  DONT INSTALL MATCHMAKING IS WORST      1
# 217573                           Your matchmaking sucks..      2
# 217590                                   THE GAME IS DEAD      1
# 217607                                       Lost account      1
# 218667  Well made..i wish more skin to come.and pls ma...      3
#
#         thumbsUpCount reviewCreatedVersion                   at  \
# 0                   0           4.0.0.6270  2023-02-28 23:52:36
# 1                  79           4.0.0.6270  2023-02-07 03:21:16
# 2                   0           4.0.0.6270  2023-03-01 16:45:36
# 3                 342           4.0.0.6270  2023-01-25 11:28:18
# 4                  47           4.0.0.6270  2023-01-25 10:12:39
# ...               ...                  ...                  ...
# 216858              0              1.1.9.0  2020-06-29 08:32:51
# 217573              0              1.1.9.0  2020-09-16 15:34:42
# 217590              2              1.1.9.0  2020-04-16 23:27:24
# 217607              0              1.1.9.0  2021-09-27 17:58:51
# 218667              0              1.1.7.0  2020-01-24 09:38:59
#
#                                              replyContent           repliedAt  \
# 0                                                    None                 NaT
# 1                                                    None                 NaT
# 2                                                    None                 NaT
# 3                                                    None                 NaT
# 4                                                    None                 NaT
# ...                                                   ...                 ...
# 216858                                               None                 NaT
# 217573                                               None                 NaT
# 217590                                               None                 NaT
# 217607  Hi, please try to create a new account on the ... 2021-09-29 08:15:32
# 218667                                               None                 NaT
#
#                             app_name
# 0       League of Legends: Wild Rift
# 1       League of Legends: Wild Rift
# 2       League of Legends: Wild Rift
# 3       League of Legends: Wild Rift
# 4       League of Legends: Wild Rift
# ...                              ...
# 216858                Heroes Evolved
# 217573                Heroes Evolved
# 217590                Heroes Evolved
# 217607                Heroes Evolved
# 218667                Heroes Evolved
#
# [180960 rows x 11 columns]

# %%
app_reviews_df_clear.score.value_counts()
# Out:
# 5    61780
# 1    58312
# 4    24035
# 3    21013
# 2    15820
# Name: score, dtype: int64

# %%
app_reviews_df_clear.to_pickle('/content/drive/MyDrive/Tesis/saved_data/review_scrap_up2.pkl')
# app_reviews_df.to_csv('/content/drive/MyDrive/Tesis/reviews_MOBA#1.csv', index=None, header=True)

# %%
type(app_reviews_df['content'][0][0])
# Out:
# str
